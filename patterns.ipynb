# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
from final_patterns.custom_schema import custom_schema

from final_patterns.fibonacci import *
from final_patterns.candlesticks import *
from final_patterns.wtc_patterns import *
from final_patterns.market_stages import *
from final_patterns.head_shoulders import *
from final_patterns.fair_value_gaps import *
from final_patterns.support_resistances import *
from final_patterns.multiple_tops_bottoms import *

# %% [markdown]
# # HEAD AND SHOULDERS

# %%
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_hs_patterns(df)

# %% [markdown]
# # MULTIPLE TOPS BOTTOMS

# %%
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_multiple_top_bottom_patterns(df)

# %% [markdown]
# # FAIR VALUE GAPS

# %%
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_fvgs(df)

# %% [markdown]
# # SUPPORT RESISTANCES

# %%
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_HSAR_levels(df)

# %% [markdown]
# # FIBONAACI EXTENSIONS

# %%
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_fibonacci_levels(df)

# %% [markdown]
# # CANDLESTICK PATTERNS

# %%
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_candlestick_with_patterns(df)

# %% [markdown]
# # MARKET STAGES

# %%
import pandas as pd
df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_stage_detections(df)

# %% [markdown]
# # PATTERNS

# %%
import pandas as pd

df = pd.read_csv("aapl.csv")
df['Date'] = pd.to_datetime(df['Date'], format="mixed")

plot_wtc_patterns(df)
